# %% [raw]
# ---
# description: Definition of utility functions that deal with simple but recurrent transformations.
# output-file: utils.html
# title: Utils
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# ## Training utilities

# %%
#|output: asis
#| echo: false
show_doc(plot_exploration)
# Out:
# ---
#
# [source](https://github.com/BorjaRequena/BOUNCE/tree/master/blob/master/BOUNCE/utils.py#L81){target="_blank" style="float:right; font-size:smaller"}
#
# ### plot_exploration
#
# >      plot_exploration (exploration_results, expl_optims=True,
# >                        highlight_max=False, figsize=(10, 5), fontsize=18,
# >                        ticksize=14)
#
# Plots exploration results. It shows the best bound obtained for every new visited state.
# If `expl_optims=True`, it also shows the proximity to the optimal relaxation.

# %%
#|output: asis
#| echo: false
show_doc(best_so_far)
# Out:
# ---
#
# [source](https://github.com/BorjaRequena/BOUNCE/tree/master/blob/master/BOUNCE/utils.py#L73){target="_blank" style="float:right; font-size:smaller"}
#
# ### best_so_far
#
# >      best_so_far (m)
#
# Returns best value up to each point along the second axis of a matrix for each row.

# %%
#|output: asis
#| echo: false
show_doc(arrange_shape)
# Out:
# ---
#
# [source](https://github.com/BorjaRequena/BOUNCE/tree/master/blob/master/BOUNCE/utils.py#L56){target="_blank" style="float:right; font-size:smaller"}
#
# ### arrange_shape
#
# >      arrange_shape (obj, mode='expand')
#
# Makes all lists within a list have the same length. Can be mode 'cut' or 'expand'

# %%
#|output: asis
#| echo: false
show_doc(plot_trainings)
# Out:
# ---
#
# [source](https://github.com/BorjaRequena/BOUNCE/tree/master/blob/master/BOUNCE/utils.py#L22){target="_blank" style="float:right; font-size:smaller"}
#
# ### plot_trainings
#
# >      plot_trainings (training_results, eval_optims=True, expl_optims=False,
# >                      figsize=(10, 5), fontsize=18, ticksize=14)
#
# Plots the training results.

# %%
#|output: asis
#| echo: false
show_doc(get_indiv_times)
# Out:
# ---
#
# [source](https://github.com/BorjaRequena/BOUNCE/tree/master/blob/master/BOUNCE/utils.py#L133){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_indiv_times
#
# >      get_indiv_times (tl_eval, convergence_crit=None)
#
# Provides convergence times from individual ratios.

# %%
#|output: asis
#| echo: false
show_doc(indiv_convergence_time)
# Out:
# ---
#
# [source](https://github.com/BorjaRequena/BOUNCE/tree/master/blob/master/BOUNCE/utils.py#L126){target="_blank" style="float:right; font-size:smaller"}
#
# ### indiv_convergence_time
#
# >      indiv_convergence_time (results, max_epochs=800, tol=0.0005, T=50,
# >                              t_avg=20, return_diffs=False)
#
# Similar to `convergence_time` but with each agent.

# %%
#|output: asis
#| echo: false
show_doc(convergence_time)
# Out:
# ---
#
# [source](https://github.com/BorjaRequena/BOUNCE/tree/master/blob/master/BOUNCE/utils.py#L112){target="_blank" style="float:right; font-size:smaller"}
#
# ### convergence_time
#
# >      convergence_time (results, tol=0.0005, T=50, t_avg=20,
# >                        return_diffs=False)
#
# Returns the convergence with criterion of not changing result by `tol` for `T` epochs.

# %% [markdown]
# ## Load and save data

# %%
#|output: asis
#| echo: false
show_doc(CPU_Unpickler)
# Out:
# ---
#
# [source](https://github.com/BorjaRequena/BOUNCE/tree/master/blob/master/BOUNCE/utils.py#L150){target="_blank" style="float:right; font-size:smaller"}
#
# ### CPU_Unpickler
#
# >      CPU_Unpickler (file, fix_imports=True, encoding='ASCII', errors='strict')
#
# Unpickles from GPU to CPU

# %%
#|output: asis
#| echo: false
show_doc(checkpoint2results)
# Out:
# ---
#
# [source](https://github.com/BorjaRequena/BOUNCE/tree/master/blob/master/BOUNCE/utils.py#L218){target="_blank" style="float:right; font-size:smaller"}
#
# ### checkpoint2results
#
# >      checkpoint2results (N, model, budget=None, IDs=None, episode=None)
#
# Loads checkpoints from IDs and converts them to result format.

# %%
#|output: asis
#| echo: false
show_doc(load_checkpoint)
# Out:
# ---
#
# [source](https://github.com/BorjaRequena/BOUNCE/tree/master/blob/master/BOUNCE/utils.py#L214){target="_blank" style="float:right; font-size:smaller"}
#
# ### load_checkpoint
#
# >      load_checkpoint (problem, budget, ID, episode)

# %%
#|output: asis
#| echo: false
show_doc(load_benchmark)
# Out:
# ---
#
# [source](https://github.com/BorjaRequena/BOUNCE/tree/master/blob/master/BOUNCE/utils.py#L205){target="_blank" style="float:right; font-size:smaller"}
#
# ### load_benchmark
#
# >      load_benchmark (problem, budget, method, suffix=None)
#
# Loads benchmark data.

# %%
#|output: asis
#| echo: false
show_doc(save_benchmark)
# Out:
# ---
#
# [source](https://github.com/BorjaRequena/BOUNCE/tree/master/blob/master/BOUNCE/utils.py#L196){target="_blank" style="float:right; font-size:smaller"}
#
# ### save_benchmark
#
# >      save_benchmark (benchmark, problem, budget, method, suffix=None)
#
# Saves benchmark data.

# %%
#|output: asis
#| echo: false
show_doc(load_model)
# Out:
# ---
#
# [source](https://github.com/BorjaRequena/BOUNCE/tree/master/blob/master/BOUNCE/utils.py#L191){target="_blank" style="float:right; font-size:smaller"}
#
# ### load_model
#
# >      load_model (problem, budget, ID)
#
# Loads agent model and parameters.

# %%
#|output: asis
#| echo: false
show_doc(save_model)
# Out:
# ---
#
# [source](https://github.com/BorjaRequena/BOUNCE/tree/master/blob/master/BOUNCE/utils.py#L186){target="_blank" style="float:right; font-size:smaller"}
#
# ### save_model
#
# >      save_model (agent, problem, budget, ID)
#
# Saves agent model and parameters.

# %%
#|output: asis
#| echo: false
show_doc(get_checkpoint_file_name)
# Out:
# ---
#
# [source](https://github.com/BorjaRequena/BOUNCE/tree/master/blob/master/BOUNCE/utils.py#L182){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_checkpoint_file_name
#
# >      get_checkpoint_file_name (problem, budget, ID, episode)
#
# Returns a consistent file naming for checkpoints.

# %%
#|output: asis
#| echo: false
show_doc(get_benchmark_file_name)
# Out:
# ---
#
# [source](https://github.com/BorjaRequena/BOUNCE/tree/master/blob/master/BOUNCE/utils.py#L178){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_benchmark_file_name
#
# >      get_benchmark_file_name (problem, budget, method)
#
# Returns a consistent file naming for benchmarks.

# %%
#|output: asis
#| echo: false
show_doc(get_memory_file_name)
# Out:
# ---
#
# [source](https://github.com/BorjaRequena/BOUNCE/tree/master/blob/master/BOUNCE/utils.py#L173){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_memory_file_name
#
# >      get_memory_file_name (problem, solver)
#
# Returns a consistent file naming for memories.

# %%
#|output: asis
#| echo: false
show_doc(get_agent_file_name)
# Out:
# ---
#
# [source](https://github.com/BorjaRequena/BOUNCE/tree/master/blob/master/BOUNCE/utils.py#L169){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_agent_file_name
#
# >      get_agent_file_name (problem, budget, ID)
#
# Returns a consistent file naming for agents.

# %%
#|output: asis
#| echo: false
show_doc(get_problem_file_name)
# Out:
# ---
#
# [source](https://github.com/BorjaRequena/BOUNCE/tree/master/blob/master/BOUNCE/utils.py#L162){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_problem_file_name
#
# >      get_problem_file_name (problem)
#
# Returns a consistent file naming from a problem instance.

# %% [markdown]
# ## State transformations

# %%
#|output: asis
#| echo: false
show_doc(action_mask)
# Out:
# ---
#
# [source](https://github.com/BorjaRequena/BOUNCE/tree/master/blob/master/BOUNCE/utils.py#L315){target="_blank" style="float:right; font-size:smaller"}
#
# ### action_mask
#
# >      action_mask (state, basis)
#
# Mask of the actions that can be performed. Better to use `SdPEnvironment.action_mask` if
# possible, it's much faster.

# %%
#|output: asis
#| echo: false
show_doc(contained_constraints)
# Out:
# ---
#
# [source](https://github.com/BorjaRequena/BOUNCE/tree/master/blob/master/BOUNCE/utils.py#L301){target="_blank" style="float:right; font-size:smaller"}
#
# ### contained_constraints
#
# >      contained_constraints (state, basis)
#
# Returns a mask indicating which constraints in the `state` are contained by larger elements
# of the basis in the same state, excluding themselves. Better to use the
# `SdPEnvironment.contained_constraints` method when possible (it's faster).

# %%
#|output: asis
#| echo: false
show_doc(add_subgraph_size)
# Out:
# ---
#
# [source](https://github.com/BorjaRequena/BOUNCE/tree/master/blob/master/BOUNCE/utils.py#L288){target="_blank" style="float:right; font-size:smaller"}
#
# ### add_subgraph_size
#
# >      add_subgraph_size (subgraphs)
#
# Takes a list of subgraphs up to any given size and adds a sublist with all the possible
# subgraphs of a larger size. It assumes the graph edges as minimal graph size.

# %%
#|output: asis
#| echo: false
show_doc(flip)
# Out:
# ---
#
# [source](https://github.com/BorjaRequena/BOUNCE/tree/master/blob/master/BOUNCE/utils.py#L282){target="_blank" style="float:right; font-size:smaller"}
#
# ### flip
#
# >      flip (state, i)
#
# Flips constraint `i` from state.

# %%
#|output: asis
#| echo: false
show_doc(T)
# Out:
# ---
#
# [source](https://github.com/BorjaRequena/BOUNCE/tree/master/blob/master/BOUNCE/utils.py#L278){target="_blank" style="float:right; font-size:smaller"}
#
# ### T
#
# >      T (state)
#
# Takes state and converts it to `torch.FloatTensor`

# %%
#|output: asis
#| echo: false
show_doc(state2str)
# Out:
# ---
#
# [source](https://github.com/BorjaRequena/BOUNCE/tree/master/blob/master/BOUNCE/utils.py#L274){target="_blank" style="float:right; font-size:smaller"}
#
# ### state2str
#
# >      state2str (state)
#
# Takes state vector and outputs a (spaceless) string.

# %%
#|output: asis
#| echo: false
show_doc(state2int)
# Out:
# ---
#
# [source](https://github.com/BorjaRequena/BOUNCE/tree/master/blob/master/BOUNCE/utils.py#L270){target="_blank" style="float:right; font-size:smaller"}
#
# ### state2int
#
# >      state2int (state)
#
# Takes state vector as binary encoding of an integer.

# %%
#|output: asis
#| echo: false
show_doc(fill_layout)
# Out:
# ---
#
# [source](https://github.com/BorjaRequena/BOUNCE/tree/master/blob/master/BOUNCE/utils.py#L263){target="_blank" style="float:right; font-size:smaller"}
#
# ### fill_layout
#
# >      fill_layout (L, N)
#
# Fills layout with single-body terms that are missing.

# %%
#|output: asis
#| echo: false
show_doc(simplify_layout)
# Out:
# ---
#
# [source](https://github.com/BorjaRequena/BOUNCE/tree/master/blob/master/BOUNCE/utils.py#L252){target="_blank" style="float:right; font-size:smaller"}
#
# ### simplify_layout
#
# >      simplify_layout (L)
#
# Simplifies the given layout of the form `[np.array([0, 1]), np.array([0, 1, 2])]`.

# %% [markdown]
# ## Array operations

# %%
#|output: asis
#| echo: false
show_doc(arrayfy)
# Out:
# ---
#
# [source](https://github.com/BorjaRequena/BOUNCE/tree/master/blob/master/BOUNCE/utils.py#L325){target="_blank" style="float:right; font-size:smaller"}
#
# ### arrayfy
#
# >      arrayfy (inp, size)
#
# Transforms input into an array of the desired size.

# %%
#|output: asis
#| echo: false
show_doc(array_in_list)
# Out:
# ---
#
# [source](https://github.com/BorjaRequena/BOUNCE/tree/master/blob/master/BOUNCE/utils.py#L321){target="_blank" style="float:right; font-size:smaller"}
#
# ### array_in_list
#
# >      array_in_list (array, array_list)
#
# Checks whether an array is in a list of arrays.

# %% [markdown]
# ## Mathematical operations

# %%
#|output: asis
#| echo: false
show_doc(binomial)
# Out:
# ---
#
# [source](https://github.com/BorjaRequena/BOUNCE/tree/master/blob/master/BOUNCE/utils.py#L342){target="_blank" style="float:right; font-size:smaller"}
#
# ### binomial
#
# >      binomial (n, k)

# %%
#|output: asis
#| echo: false
show_doc(dist_poly)
# Out:
# ---
#
# [source](https://github.com/BorjaRequena/BOUNCE/tree/master/blob/master/BOUNCE/utils.py#L336){target="_blank" style="float:right; font-size:smaller"}
#
# ### dist_poly
#
# >      dist_poly (x, xmin, xmax, d)
#
# Computes a linear decay bound from 1 to 0 given a minimum and maximum value (in terms of
# absolute value). Exponentiate the line to get better shapes

# %%
#|output: asis
#| echo: false
show_doc(dist_exp)
# Out:
# ---
#
# [source](https://github.com/BorjaRequena/BOUNCE/tree/master/blob/master/BOUNCE/utils.py#L332){target="_blank" style="float:right; font-size:smaller"}
#
# ### dist_exp
#
# >      dist_exp (xmin, x)
#
# Computes an eponential distance given a minimum value (in terms of absolute value).

# %%
#| include: false
from nbdev import nbdev_export
nbdev_export()
# Out:
# Converted 00_environment.ipynb.
# Converted 01_agents.ipynb.
# Converted 02_budget_profiles.ipynb.
# Converted 03_hamiltonian.ipynb.
# Converted 04_training.ipynb.
# Converted 05_utils.ipynb.
# Converted 06_sdp.ipynb.
# Converted index.ipynb.
